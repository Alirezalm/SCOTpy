# %% [markdown]
# ### Distributed Sparse Logistic Regression (DSLR)
#
# This notebook explains how to solve a random data DSLR problem with ```SCOTpy``` API. First install the ```SCOTPY``` package by executing
# ```command
# pip install scotpy
# ```
# Make sure ```GUROBI_HOME``` and ```SCOT_BIN``` environment variables are defined.
#
# ```
# export GUROBI_HOME=/path/to/gurobi/home/dir
# ```
# #### Importing necessary classes

# %%
from typing import List

from sklearn.datasets import make_classification

from scotpy import (AlgorithmType,
                    ProblemType,
                    ScotModel,
                    ScotPy,
                    ScotSettings
                    )

# %% [markdown]
# ### Creating problem data
#
# In this step we create ```ScotModel``` objects with random classification data for 4 computational nodes.

# %%
total_nodes = 4

models: List[ScotModel] = []

number_of_nonzeros = 5

for mpi_rank in range(total_nodes):
    dataset, res = make_classification(n_samples=2000, n_features=10) # creating 2000 samples for each computational node

    scp = ScotModel(problem_name="classification", rank=mpi_rank, kappa=number_of_nonzeros, ptype=ProblemType.CLASSIFICATION) 

    scp.set_data(dataset, res, normalized_data=True)

    scp.create()

    models.append(scp)
# Out:
# /home/alireza/scotpy/inputs/node_0_classification.dist.json created.
# /home/alireza/scotpy/inputs/node_1_classification.dist.json created.
# /home/alireza/scotpy/inputs/node_2_classification.dist.json created.
# /home/alireza/scotpy/inputs/node_3_classification.dist.json created.

# %% [markdown]
# ### Solver settings
# In this step, we setup scot by using the ```ScotSettings``` class.

# %%
 scot_settings = ScotSettings(
        relative_gap=1e-4, #relative optimality gap tolerance used by scot solver
        time_limit=500,    # maximum execution time limit
        verbose=True,      # verbosity
        algorithm=AlgorithmType.DIHOA, # MINLP algorithm; DIHOA or DIPOA
        ub=30 # upper bound guess on parameters. don't state it if you don't have any guesses. 
    )

# %% [markdown]
# ### Create solver object
#
# In this step, we create scot solver object by instantiating ```ScotPy``` class as follows.

# %%
solver = ScotPy(models, scot_settings)

# %% [markdown]
# ### Solving the optimization problem and retreiving the results.

# %%
objval, solution, execution_time = solver.run()

print(f"Optimal Objective Value: {objval}")
print(f"Optimal Solution: {solution}")
print(f"Execution Time: {execution_time} seconds")
# Out:
# /home/alireza/scotpy/inputs/node_2_classification.dist.json: ✓
# /home/alireza/scotpy/inputs/node_0_classification.dist.json: ✓
# /home/alireza/scotpy/inputs/node_1_classification.dist.json: ✓
# /home/alireza/scotpy/inputs/node_3_classification.dist.json: ✓
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-09-13
#
#
# ―――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Sparse Convex Optimization Toolkit (SCOT)
#
# a distributed MINLP Solver based on MPI   ---   v0.1.0
#
# Alireza Olama - Federal University of Santa Catarina (UFSC), Brazil
#
# email: alireza.lm69@gmail.com
# github: github.com/alirezalm/scot
#
# Problem details:
# ―――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# 	number of nodes: 4
# 	problem type: Sparse Classification
# 	number of variables: 10
# 	number of rows per node: 2000
# 	total number of rows: 8000
# 	number of nonzeros: 5
# 	bigM parameter: 30
#
#
# SCOT settings:
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# 	Algorithm: dihoa
#
# NLP solver settings:
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# 	Algorithm Type: Distributed
# 	Algorithm name: RHADMM
# 	Distributed computing framework: Message Passing Interface (MPI)
#
# MIP solver settings:
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# 	Solver name: Gurobi
#
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Set parameter Username
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-09-13
# Academic license - for non-commercial use only - expires 2024-09-13
#        Cut Info        |     Objective Bounds      |      Gap Info  |  Elapsed
#    FOC             SOC | Incumbent      dual | abs              rel |
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-09-13
# Warning: zero or small (< 1e-13) coefficients in quadratic constraints, ignored
# Warning: zero or small (< 1e-13) coefficients in quadratic constraints, ignored
# Warning: zero or small (< 1e-13) coefficients in quadratic constraints, ignored
# Warning: zero or small (< 1e-13) coefficients in quadratic constraints, ignored
#      4              0 | 2.7726        -25.0446 | 27.8172      10.0329 | 0.0071 s
#      8              0 | 1.8723        -0.9350 | 2.8073      1.4994 | 0.2774 s
#     12              0 | 1.8723        0.0871 | 1.7852      0.9535 | 0.6129 s
#     16              0 | 1.8723        0.3661 | 1.5062      0.8045 | 0.9711 s
#     20              0 | 1.8723        0.5450 | 1.3273      0.7089 | 1.5052 s
#     24              0 | 1.8224        1.3292 | 0.4931      0.2706 | 1.7902 s
#     28              0 | 1.8224        1.4817 | 0.3406      0.1869 | 2.1628 s
#     32              0 | 1.8224        1.6453 | 0.1770      0.0971 | 2.4469 s
#     36              0 | 1.8224        1.7202 | 0.1021      0.0560 | 2.7886 s
#     40              0 | 1.8224        1.7269 | 0.0954      0.0524 | 3.2326 s
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 10000
# Set parameter LazyConstraints to value 1
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 10000
# Set parameter LazyConstraints to value 1
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 10000
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (linux64)
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (linux64)
#
# CPU model: Intel(R) Core(TM) i5-10300H CPU @ 2.50GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 21 rows, 24 columns and 50 nonzeros
# Model fingerprint: 0x1b9c0222
# Model has 44 quadratic constraints
# Variable types: 14 continuous, 10 integer (10 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   QLMatrix range   [2e-05, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+00, 5e+00]
#   QRHS range       [4e-01, 7e-01]
#
# MIP start from previous solve produced solution with objective 1.88098 (0.00s)
# Loaded MIP start from previous solve with objective 1.88098
#
# Presolve added 44 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 65 rows, 24 columns, 534 nonzeros
# Variable types: 14 continuous, 10 integer (10 binary)
#
# Root relaxation: objective 1.398133e+00, 46 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    1.39813    0    8    1.88098    1.39813  25.7%     -    0s
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (linux64)
#
# CPU model: Intel(R) Core(TM) i5-10300H CPU @ 2.50GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 21 rows, 24 columns and 50 nonzeros
# Model fingerprint: 0x1b9c0222
# Model has 44 quadratic constraints
# Variable types: 14 continuous, 10 integer (10 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   QLMatrix range   [2e-05, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+00, 5e+00]
#   QRHS range       [4e-01, 7e-01]
#
# MIP start from previous solve produced solution with objective 1.88098 (0.00s)
# Loaded MIP start from previous solve with objective 1.88098
#
# Presolve added 44 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 65 rows, 24 columns, 534 nonzeros
# Variable types: 14 continuous, 10 integer (10 binary)
#
# Root relaxation: objective 1.398133e+00, 46 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    1.39813    0    8    1.88098    1.39813  25.7%     -    0s
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 10000
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (linux64)
#
# CPU model: Intel(R) Core(TM) i5-10300H CPU @ 2.50GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 21 rows, 24 columns and 50 nonzeros
# Model fingerprint: 0x1b9c0222
# Model has 44 quadratic constraints
# Variable types: 14 continuous, 10 integer (10 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   QLMatrix range   [2e-05, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+00, 5e+00]
#   QRHS range       [4e-01, 7e-01]
#
# MIP start from previous solve produced solution with objective 1.88098 (0.00s)
# Loaded MIP start from previous solve with objective 1.88098
#
# Presolve added 44 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 65 rows, 24 columns, 534 nonzeros
# Variable types: 14 continuous, 10 integer (10 binary)
#
# Root relaxation: objective 1.398133e+00, 46 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    1.39813    0    8    1.88098    1.39813  25.7%     -    0s
#
# CPU model: Intel(R) Core(TM) i5-10300H CPU @ 2.50GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 21 rows, 24 columns and 50 nonzeros
# Model fingerprint: 0x1b9c0222
# Model has 44 quadratic constraints
# Variable types: 14 continuous, 10 integer (10 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   QLMatrix range   [2e-05, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+00, 5e+00]
#   QRHS range       [4e-01, 7e-01]
#
# MIP start from previous solve produced solution with objective 1.88098 (0.00s)
# Loaded MIP start from previous solve with objective 1.88098
#
# Presolve added 44 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 65 rows, 24 columns, 534 nonzeros
# Variable types: 14 continuous, 10 integer (10 binary)
#      0     0    1.46546    0    8    1.88098    1.46546  22.1%     -    0s
#
# Root relaxation: objective 1.398133e+00, 46 iterations, 0.00 seconds (0.00 work units)
# H    0     0                       1.8501407    1.46546  20.8%     -    0s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    1.39813    0    8    1.88098    1.39813  25.7%     -    0s
#      0     0    1.49716    0    7    1.85014    1.49716  19.1%     -    0s
#      0     0    1.46546    0    8    1.88098    1.46546  22.1%     -    0s
# H    0     0                       1.8501407    1.46546  20.8%     -    0s
#      0     0    1.52654    0    7    1.85014    1.52654  17.5%     -    0s
#      0     0    1.49716    0    7    1.85014    1.49716  19.1%     -    0s
#      0     0    1.46546    0    8    1.88098    1.46546  22.1%     -    0s
#      0     0    1.46546    0    8    1.88098    1.46546  22.1%     -    0s
# H    0     0                       1.8501407    1.46546  20.8%     -    0s
# H    0     0                       1.8501407    1.46546  20.8%     -    0s
#      0     0    1.49716    0    7    1.85014    1.49716  19.1%     -    0s
#      0     0    1.49716    0    7    1.85014    1.49716  19.1%     -    0s
#      0     0    1.52654    0    7    1.85014    1.52654  17.5%     -    0s
#      0     0    1.52654    0    7    1.85014    1.52654  17.5%     -    0s
#      0     0    1.52654    0    7    1.85014    1.52654  17.5%     -    0s
# H    0     0                       1.8473048    1.52654  17.4%     -    0s
# H    0     0                       1.8473048    1.52654  17.4%     -    0s
# H    0     0                       1.8473048    1.52654  17.4%     -    0s
# H    0     0                       1.8473048    1.52654  17.4%     -    0s
#      0     2    1.52654    0    7    1.84730    1.52654  17.4%     -    0s
#      0     2    1.52654    0    7    1.84730    1.52654  17.4%     -    0s
#      0     2    1.52654    0    7    1.84730    1.52654  17.4%     -    0s
#      0     2    1.52654    0    7    1.84730    1.52654  17.4%     -    0s
# *   44    15               8       1.8390698    1.56520  14.9%   7.4    9s
# *   44    15               8       1.8390698    1.56520  14.9%   7.4    9s
# *   44    15               8       1.8390698    1.56520  14.9%   7.4    9s
# *   44    15               8       1.8390698    1.56520  14.9%   7.4    9s
# *   72    15               8       1.8349730    1.62232  11.6%   7.7   16s
# *   72    15               8       1.8349730    1.62232  11.6%   7.7   16s
# *   72    15               8       1.8349730    1.62232  11.6%   7.7   16s
# *   72    15               8       1.8349730    1.62232  11.6%   7.7   16s
# *   90    17               6       1.8300290    1.71033  6.54%   7.5   21s
# *  101    17               8       1.8294593    1.71599  6.20%   7.6   21s
# *   90    17               6       1.8300290    1.71033  6.54%   7.5   21s
# *  101    17               8       1.8294593    1.71599  6.20%   7.6   21s
# *   90    17               6       1.8300290    1.71033  6.54%   7.5   21s
# *   90    17               6       1.8300290    1.71033  6.54%   7.5   21s
# *  101    17               8       1.8294593    1.71599  6.20%   7.6   21s
# *  101    17               8       1.8294593    1.71599  6.20%   7.6   21s
# *  111     9               7       1.8222062    1.77556  2.56%   7.6   26s
# *  111     9               7       1.8222062    1.77556  2.56%   7.6   26s
# *  111     9               7       1.8222062    1.77556  2.56%   7.6   26s
# *  111     9               7       1.8222062    1.77556  2.56%   7.6   26s
#
# Cutting planes:
#   Gomory: 5
#   Lazy constraints: 40
#
# Explored 142 nodes (1146 simplex iterations) in 31.46 seconds (0.02 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 8: 1.82221 1.82946 1.83003 ... 1.88098
#
# Cutting planes:
#   Gomory: 5
#   Lazy constraints: 40
#
# Explored 142 nodes (1146 simplex iterations) in 31.46 seconds (0.02 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 8: 1.82221 1.82946 1.83003 ... 1.88098
#
# Optimal solution found (tolerance 1.00e-08)
#
# Optimal solution found (tolerance 1.00e-08)
# Best objective 1.822206196290e+00, best bound 1.822206196290e+00, gap 0.0000%
# Best objective 1.822206196290e+00, best bound 1.822206196290e+00, gap 0.0000%
#
# User-callback calls 490, time in user-callback 31.33 sec
#
# Solution Report:
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# 	SCOT converged successfully
# 	Optimal objective value: 1.8224
# 	Execution time: 35.2556 seconds
#
# Cutting planes:
#   Gomory: 5
#   Lazy constraints: 40
#
# Explored 142 nodes (1146 simplex iterations) in 31.47 seconds (0.02 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 8: 1.82221 1.82946 1.83003 ... 1.88098
#
# Optimal solution found (tolerance 1.00e-08)
# Best objective 1.822206196290e+00, best bound 1.822206196290e+00, gap 0.0000%
#
# User-callback calls 494, time in user-callback 31.22 sec
#
# Solution Report:
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# 	SCOT converged successfully
# 	Optimal objective value: 1.8224
# 	Execution time: 35.2548 seconds
#
# User-callback calls 494, time in user-callback 31.15 sec
#
# Cutting planes:
#   Gomory: 5
#   Lazy constraints: 40
#
# Explored 142 nodes (1146 simplex iterations) in 31.47 seconds (0.02 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 8: 1.82221 1.82946 1.83003 ... 1.88098
#
# Optimal solution found (tolerance 1.00e-08)
# Best objective 1.822206196290e+00, best bound 1.822206196290e+00, gap 0.0000%
#
# Solution Report:
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# 	SCOT converged successfully
# 	Optimal objective value: 1.8224
# 	Execution time: 35.2592 seconds
#
# User-callback calls 484, time in user-callback 31.23 sec
#
# Solution Report:
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# 	SCOT converged successfully
# 	Optimal objective value: 1.8224
# 	Execution time: 35.2615 seconds
# Optimal Objective Value: [-0.06747238  0.          0.          2.70297414  0.          0.
#  -1.69422539  0.          1.90731616  4.94352178]
# Optimal Solution: 35.26154221
# Execution Time: 1.8591791800146813 seconds
